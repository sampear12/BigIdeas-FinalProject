# %% [markdown]
# **Henry Wilson**
#
# # Best Neighborhood for a Triathalon
#
# ## General note
#
# I know this isn't really the format this project should be in, but it has helped me streamline  my thinking to write everything out this way. I'll condense it (and add more) when it gets to the final.
#
# ## Best Neighborhood for Swimming
#
# Pittsburgh is holding a triathalon -- but where should the swim take place?
#
# I figured that, given both the participant base and length of a triathalon, the best place to start would be to look at the Three Rivers. But while many see the rivers as a nice place for boats, bridges, and natural life, countless Pittsburgh companies see these same rivers as prime space to dispose of harmful chemicals and carcinogens. So... we don't really want people swimming in that. Good thing the EPA releases an annual report on toxic substances released into the air, land, and water.
#
# Dataset: [Toxic Release Inventory - Waterways](https://data.wprdc.org/dataset/toxic-release-inventory)
#
# For this dataset I wanted to look at a few metrics.
#
# #### 1. What neighborhoods have access to the three rivers?
#
# This one is given. If you can't reach it by land, you can't have people swim there.
#
# #### 2a. What river has had the most spills? (by number)
#
# Although some spills happened decades ago, a safe and effective way to whittle down which river to use would be to find the one with the least amount of spills in it.
#
# #### 2b. What river has had the most spills (by amount disposed)
#
# The TRI also gives some data on the amount of toxic released into a given place. This should be useful as well
#
# #### 3. Where did the spills happen?
#
# The TRI gives data on where the spills happened.
#
# #### 4. Air quality
#
# Data is also provided regarding clean air -- this should be put into consideration as well.

# %% [markdown]
# ----

# %% [markdown]
# ## Part X: What river has had the most spills?

# %% [markdown]
# #### Importing the dataset

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

water = pd.read_csv("waterways.csv")

water.head(10)
# Out:
#    TRI_FACILITY_ID   DOC_CTRL_NUM                               FACILITY_NAME  \
# 0  15226MTTHW1315W  1396105260741                 MATTHEWS INTERNATIONAL CORP
# 1  15025RSTCH400ST  1388025294164              KOPPERS INC CLAIRTON TAR PLANT
# 2  15144PPGND125CO  1310208167751        PPG INDUSTRIESINC-SPRINGDALE COMPLEX
# 3  15139TRNGL931TH  1389035450600                        GLOBAL CIRCUITS INC.
# 4  15020SNCCHBUNOL  1302200503023    UNIVAR SOLUTIONS USA INC - BUNOLA BRANCH
# 5  15148LLGHN999AI  1314212463727             ALLEGHENY PETROLEUM PRODUCTS CO
# 6  15025RSTCH400ST  1390045279217              KOPPERS INC CLAIRTON TAR PLANT
# 7  15025RSTCH400ST  1390045279217              KOPPERS INC CLAIRTON TAR PLANT
# 8  15233THVLS2000W  1393070296494                         SHERWIN-WILLIAMS CO
# 9  15104SSDGRBRADD  1312210512758  USS MON VALLEY WORKS - EDGAR THOMSON PLANT
#
#            STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# 0      1315 W LIBERTY AVE  PITTSBURGH   ALLEGHENY                   42003
# 1          300 N STATE ST    CLAIRTON   ALLEGHENY                   42003
# 2           125 COLFAX ST  SPRINGDALE   ALLEGHENY                   42003
# 3              931 3RD ST     OAKMONT   ALLEGHENY                   42003
# 4     328 BUNOLA RIVER RD      BUNOLA   ALLEGHENY                   42003
# 5        999 AIRBRAKE AVE  WILMERDING   ALLEGHENY                   42003
# 6          300 N STATE ST    CLAIRTON   ALLEGHENY                   42003
# 7          300 N STATE ST    CLAIRTON   ALLEGHENY                   42003
# 8        2000 WESTHALL ST  PITTSBURGH   ALLEGHENY                   42003
# 9  BRADDOCK AVE & 13TH ST    BRADDOCK   ALLEGHENY                   42003
#
#   STATE_ABBR  ZIP_CODE  REGION  ...  RELEASE_RANGE_CODE TOTAL_RELEASE  \
# 0         PA     15226       3  ...                 NaN           NaN
# 1         PA     15025       3  ...                 NaN           0.0
# 2         PA     15144       3  ...                 NaN           NaN
# 3         PA     15139       3  ...                 NaN           NaN
# 4         PA     15020       3  ...                 NaN           NaN
# 5         PA     15148       3  ...                 NaN           NaN
# 6         PA     15025       3  ...                 NaN           0.0
# 7         PA     15025       3  ...                 NaN           NaN
# 8         PA     15233       3  ...                 NaN           NaN
# 9         PA     15104       3  ...                 NaN        2000.0
#
#   REL_EST_AMT RELEASE_NA RELEASE_BASIS_EST_CODE WATER_SEQUENCE_NUM  \
# 0         0.0          0                    NaN                  1
# 1         0.0          0                      O                  1
# 2         0.0          1                    NaN                  1
# 3         0.0          1                    NaN                  1
# 4         0.0          0                    NaN                  1
# 5         0.0          1                    NaN                  1
# 6         0.0          0                      O                  1
# 7         0.0          1                    NaN                  3
# 8         0.0          1                    NaN                  1
# 9      2000.0          0                     M2                  1
#
#          STREAM_NAME  STORM_WATER_NA  STORM_WATER_PERCENT REACH_CODE
# 0                NaN               0                  NaN        NaN
# 1       PETERS CREEK               0                  NaN        NaN
# 2                NaN               0                  NaN        NaN
# 3                NaN               1                  NaN        NaN
# 4                NaN               0                  NaN        NaN
# 5                NaN               0                  NaN        NaN
# 6       PETERS CREEK               0                  NaN        NaN
# 7                NaN               0                  NaN        NaN
# 8                NaN               1                  NaN        NaN
# 9  MONONGAHELA RIVER               0                 99.0        NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# There is a lot of data in the set that doesn't seem entirely necesssary for the purposes at hand. I'll start the data manipulation process by limiting the results to only spills that happened in the actual city.

# %%
water_mask = water['CITY_NAME'] == "PITTSBURGH" #only pittsburgh cases

pgh_water = water[water_mask] #apply mask
        
pgh_water.head(10)
# Out:
#     TRI_FACILITY_ID   DOC_CTRL_NUM                              FACILITY_NAME  \
# 0   15226MTTHW1315W  1396105260741                MATTHEWS INTERNATIONAL CORP
# 8   15233THVLS2000W  1393070296494                        SHERWIN-WILLIAMS CO
# 20  15201XXNCM34THS  1393075550259              EXXON CO USA PITTSBURGH PLANT
# 21  15225CLGNC200NE  1300140375647    CALGON CARBON CORP NEVILLE ISLAND PLANT
# 23  15225WTSNSCORNE  1316215159841  WATSON STANDARD CO (NEVILLE ISLAND PLANT)
# 25  15204PRTTSTABOR  1399130014855           PRUETT-SCHAFFER CHEMICAL CO INC.
# 26  15204FRRCR60GRE  1393075192157                       FERRO CORP COLOR DIV
# 28  15225NVLLC2800N  1396100386527                        NEVILLE CHEMICAL CO
# 29  15225SHNNG200NE  1391055588848                               SHENANGO INC
# 30  15225SHNNG200NE  1391055588848                               SHENANGO INC
#
#         STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# 0   1315 W LIBERTY AVE  PITTSBURGH   ALLEGHENY                   42003
# 8     2000 WESTHALL ST  PITTSBURGH   ALLEGHENY                   42003
# 20         100 35TH ST  PITTSBURGH   ALLEGHENY                   42003
# 21      200 NEVILLE RD  PITTSBURGH   ALLEGHENY                   42003
# 23      2895 GRAND AVE  PITTSBURGH   ALLEGHENY                   42003
# 25    3327 STAFFORD ST  PITTSBURGH   ALLEGHENY                   42003
# 26      60 GREENWAY DR  PITTSBURGH   ALLEGHENY                   42003
# 28     2800 NEVILLE RD  PITTSBURGH   ALLEGHENY                   42003
# 29      200 NEVILLE RD  PITTSBURGH   ALLEGHENY                   42003
# 30      200 NEVILLE RD  PITTSBURGH   ALLEGHENY                   42003
#
#    STATE_ABBR   ZIP_CODE  REGION  ...  RELEASE_RANGE_CODE TOTAL_RELEASE  \
# 0          PA      15226       3  ...                 NaN           NaN
# 8          PA      15233       3  ...                 NaN           NaN
# 20         PA      15201       3  ...                 NaN           0.0
# 21         PA      15225       3  ...                 NaN           NaN
# 23         PA      15225       3  ...                 NaN           NaN
# 25         PA      15204       3  ...                 NaN           NaN
# 26         PA  152042599       3  ...                 NaN           NaN
# 28         PA      15225       3  ...                 NaN           NaN
# 29         PA      15225       3  ...                 NaN       92000.0
# 30         PA      15225       3  ...                 NaN           NaN
#
#    REL_EST_AMT RELEASE_NA RELEASE_BASIS_EST_CODE WATER_SEQUENCE_NUM  \
# 0          0.0          0                    NaN                  1
# 8          0.0          1                    NaN                  1
# 20         0.0          0                      M                  1
# 21         0.0          0                    NaN                  1
# 23         0.0          1                    NaN                  1
# 25         0.0          0                    NaN                  1
# 26         0.0          0                    NaN                  1
# 28         0.0          0                    NaN                  2
# 29     92000.0          0                      M                  1
# 30         0.0          0                    NaN                  2
#
#                 STREAM_NAME  STORM_WATER_NA  STORM_WATER_PERCENT REACH_CODE
# 0                       NaN               0                  NaN        NaN
# 8                       NaN               1                  NaN        NaN
# 20          ALLEGHENY RIVER               0                100.0        NaN
# 21                      NaN               0                  NaN        NaN
# 23                      NaN               0                  NaN        NaN
# 25                      NaN               0                  NaN        NaN
# 26                      NaN               0                  NaN        NaN
# 28                      NaN               0                  NaN        NaN
# 29  OHIO RIVER MAIN CHANNEL               1                  NaN        NaN
# 30                      NaN               0                  NaN        NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# It looks better, but there is still a good amount of columns I'm never going to need to look at.

# %% [markdown]
# #### **Streamlining the data**

# %%
columns = ["STREET_ADDRESS","ZIP_CODE","REPORTING_YEAR",
           "CHEM_NAME","CARCINOGEN","CLEAN_AIR","TOTAL_RELEASE",
           "REL_EST_AMT","STREAM_NAME",] #only want these columns

for col in pgh_water.columns:
    if col not in columns:
        del pgh_water[col]
        
pgh_water.head(10)
# Out:
#         STREET_ADDRESS   ZIP_CODE  REPORTING_YEAR  \
# 0   1315 W LIBERTY AVE      15226            1996
# 8     2000 WESTHALL ST      15233            1993
# 20         100 35TH ST      15201            1993
# 21      200 NEVILLE RD      15225            2000
# 23      2895 GRAND AVE      15225            2016
# 25    3327 STAFFORD ST      15204            1999
# 26      60 GREENWAY DR  152042599            1993
# 28     2800 NEVILLE RD      15225            1996
# 29      200 NEVILLE RD      15225            1991
# 30      200 NEVILLE RD      15225            1991
#
#                            CHEM_NAME CARCINOGEN CLEAN_AIR  TOTAL_RELEASE  \
# 0                               Lead          Y         Y            NaN
# 8                    n-Butyl alcohol          N         N            NaN
# 20                    Zinc compounds          N         N            0.0
# 21  Dioxin and dioxin-like compounds          Y         Y            NaN
# 23            Methyl isobutyl ketone          Y         Y            NaN
# 25             Certain glycol ethers          N         Y            NaN
# 26                    Lead compounds          N         Y            NaN
# 28                           Benzene          Y         Y            NaN
# 29                           Ammonia          N         N        92000.0
# 30                           Ammonia          N         N            NaN
#
#     REL_EST_AMT              STREAM_NAME
# 0           0.0                      NaN
# 8           0.0                      NaN
# 20          0.0          ALLEGHENY RIVER
# 21          0.0                      NaN
# 23          0.0                      NaN
# 25          0.0                      NaN
# 26          0.0                      NaN
# 28          0.0                      NaN
# 29      92000.0  OHIO RIVER MAIN CHANNEL
# 30          0.0                      NaN

# %% [markdown]
# It looks better and ready to have some sort of plot.

# %% [markdown]
# #### **Plotting the data**

# %%
streams = pgh_water['STREAM_NAME'].value_counts().rename_axis("stream").to_frame(name='spills')

print(streams)
# Out:
#                               spills
# stream
# OHIO RIVER                       625
# ALLEGHENY RIVER                  255
# OHIO RIVER - MAIN CHANNEL        203
# MONONGAHELA RIVER                116
# OHIO RIVER MAIN CHANNEL           90
# OHIO RIVER  MAIN CHANNEL          35
# OHIO RIVER-MAIN CHANNEL           15
# SAWMILL RUN                       12
# MONOGAHELA RIVER                  10
# ALLEGHENY RIVER @ 9.25 MILE        8
# OH RIVER                           7
# POTW                               4
# LOWRIES RUN                        4
# LICK RUN CREEK                     3
# ALLEGHENY RIVER AT 9.25 MILE       3
# OHIO RIVER (BACK CHANNEL)          3
# 0                                  2
# OHIO RIVER, MAIN CHANNEL           2
# NANONGAHELA RIVER                  2
# MONONGAHELA ROVER                  1
# ALLEGHEN RIVER                     1
# UNIO RIVER                         1
# ALLEGHENY                          1
# OHIO RIVER - MAIN RIVER            1
# OHIO RIVER- MAIN CHANNEL           1
# ALLEGHENY RIVER @ 9.25  MILE       1
# MONOMGAHELA RIVER                  1
# ALLLEGHENY RIVER                   1

# %% [markdown]
# Getting closer, but some people at the EPA have fat fingers. How does it look though?

# %%
streams.plot.bar(title='Spills in the Three Rivers')
plt.xlabel("River")
plt.ylabel("Spills (since 1975)")
# Out:
# Text(0, 0.5, 'Spills (since 1975)')

# %% [markdown]
# #### **Getting rid of typos**

# %%
streams = pgh_water['STREAM_NAME'].value_counts().rename_axis("stream").reset_index(name='spills')
print(streams)
# Out:
#                           stream  spills
# 0                     OHIO RIVER     625
# 1                ALLEGHENY RIVER     255
# 2      OHIO RIVER - MAIN CHANNEL     203
# 3              MONONGAHELA RIVER     116
# 4        OHIO RIVER MAIN CHANNEL      90
# 5       OHIO RIVER  MAIN CHANNEL      35
# 6        OHIO RIVER-MAIN CHANNEL      15
# 7                    SAWMILL RUN      12
# 8               MONOGAHELA RIVER      10
# 9    ALLEGHENY RIVER @ 9.25 MILE       8
# 10                      OH RIVER       7
# 11                          POTW       4
# 12                   LOWRIES RUN       4
# 13                LICK RUN CREEK       3
# 14  ALLEGHENY RIVER AT 9.25 MILE       3
# 15     OHIO RIVER (BACK CHANNEL)       3
# 16                             0       2
# 17      OHIO RIVER, MAIN CHANNEL       2
# 18             NANONGAHELA RIVER       2
# 19             MONONGAHELA ROVER       1
# 20                ALLEGHEN RIVER       1
# 21                    UNIO RIVER       1
# 22                     ALLEGHENY       1
# 23       OHIO RIVER - MAIN RIVER       1
# 24      OHIO RIVER- MAIN CHANNEL       1
# 25  ALLEGHENY RIVER @ 9.25  MILE       1
# 26             MONOMGAHELA RIVER       1
# 27              ALLLEGHENY RIVER       1

# %% [markdown]
# I reverted streams so that the river names were not the index column anymore.

# %%
ohio = 0
alle = 0
mono = 0

ohio_river = ['OHIO RIVER', 'OHIO RIVER - MAIN CHANNEL', 'OHIO RIVER MAIN CHANNEL',
              'OHIO RIVER  MAIN CHANNEL', 'OHIO RIVER-MAIN CHANNEL', 'OH RIVER', 
             'OHIO RIVER - MAIN RIVER', 'OHIO RIVER- MAIN CHANNEL', 'UNIO RIVER']
alle_river = ['ALLEGHENY RIVER','ALLEGHENY RIVER @ 9.25 MILE',
              'ALLEGHENY RIVER AT 9.25 MILE','ALLEGHEN RIVER','ALLEGHENY',
              'ALLLEGHENY RIVER']
mono_river = ['MONONGAHELA RIVER','MONOGAHELA RIVER','NANONGAHELA RIVER',
              'MONONGAHELA ROVER','MONOMGAHELA RIVER']

for index, row in streams.iterrows():
    stream_name = row['stream']
    spills = row['spills']
    if stream_name in ohio_river:
        ohio += spills
    elif stream_name in alle_river:
        alle += spills
    elif stream_name in mono_river:
        mono += spills

rivers = pd.Series({"Ohio": ohio, "Allegheny": alle, "Monongahela": mono})

rivers
# Out:
# Ohio           978
# Allegheny      269
# Monongahela    130
# dtype: int64

# %% [markdown]
# #### Re-plotting

# %%
rivers.plot()

# %%
rivers.plot.bar(title='Spills in the Three Rivers')
plt.xlabel("River")
plt.ylabel("Spills (since 1975)")
# Out:
# Text(0, 0.5, 'Spills (since 1975)')

# %% [markdown]
# It looks like the Monongahela is the best from a purely non-spill perspective.
#
# We shall see as I do more data plotting.

# %% [markdown]
# ## Links
#
# [The Pittsburgh Pool](https://3r2n.collinsandgoto.com/river-research/pittsburgh-pool/index.html)
#
# [openwaterpgh](https://openwaterpgh.wordpress.com/)
